# %% [markdown]
# <a href="https://colab.research.google.com/github/JellyStradler/WorkingTogetherApartReally2/blob/main/Data_Science_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Science Project 1
# * Here is a link to the [project requirements](https://docs.google.com/document/d/1gpViNliAZ_L9o-wIEM2nYqGWSvwApCljATBcD6YDbNU/edit?usp=sharing)
# * Here is a link to built in [datasets of seaborn](https://docs.google.com/document/d/1SXqI19wZXjskz3Kn_NEcPE8l8PHt3XEkZxk-AJBwng8/edit?usp=sharing)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
electric = pd.read_csv('Electric_Vehicle_Population_Data.csv')
elec  1```tric.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             291
# 1           Clean Alternative Fuel Vehicle Eligible             150
# ...

# %%
sns.swarmplot(x='Make',y='State',data=electric                )
